# %%
import os
import shutil
from pathlib import Path

# %%
main_path = Path("/Users/vajirathambawita/Dropbox (Simula)/CHECK_POINTS/SynGAN-polyps/TrainedModels_1")

# %%
len(list(main_path.iterdir()))
# Out:
# 252

# %%
for sample_dir in main_path.iterdir():
    #print(sample_dir)

    for sub_path in sample_dir.iterdir():

        if sub_path.is_dir():

            print(sub_path) 
            shutil.rmtree(sub_path)
# Out:
# /Users/vajirathambawita/Dropbox (Simula)/CHECK_POINTS/SynGAN-polyps/TrainedModels_1/220/0
# /Users/vajirathambawita/Dropbox (Simula)/CHECK_POINTS/SynGAN-polyps/TrainedModels_1/220/7
# /Users/vajirathambawita/Dropbox (Simula)/CHECK_POINTS/SynGAN-polyps/TrainedModels_1/220/6
# /Users/vajirathambawita/Dropbox (Simula)/CHECK_POINTS/SynGAN-polyps/TrainedModels_1/220/1
# /Users/vajirathambawita/Dropbox (Simula)/CHECK_POINTS/SynGAN-polyps/TrainedModels_1/220/8
# /Users/vajirathambawita/Dropbox (Simula)/CHECK_POINTS/SynGAN-polyps/TrainedModels_1/220/4
# /Users/vajirathambawita/Dropbox (Simula)/CHECK_POINTS/SynGAN-polyps/TrainedModels_1/220/3
# /Users/vajirathambawita/Dropbox (Simula)/CHECK_POINTS/SynGAN-polyps/TrainedModels_1/220/2
# /Users/vajirathambawita/Dropbox (Simula)/CHECK_POINTS/SynGAN-polyps/TrainedModels_1/220/5
# /Users/vajirathambawita/Dropbox (Simula)/CHECK_POINTS/SynGAN-polyps/TrainedModels_1/245/0
# ...

# %%
shutil.rmtree("/Users/vajirathambawita/Dropbox (Simula)/CHECK_POINTS/SynGAN-polyps/TrainedModels_1/1_1")

# %%
for sub_path in Path("/Users/vajirathambawita/Dropbox (Simula)/CHECK_POINTS/SynGAN-polyps/TrainedModels_1/1 copy").iterdir():

    if sub_path.is_dir():

        print(sub_path)
        shutil.rmtree(sub_path)
    else:
        print("to keep:",sub_path)
# Out:
# to keep: /Users/vajirathambawita/Dropbox (Simula)/CHECK_POINTS/SynGAN-polyps/TrainedModels_1/1 copy/Zs.pth
# /Users/vajirathambawita/Dropbox (Simula)/CHECK_POINTS/SynGAN-polyps/TrainedModels_1/1 copy/0
# /Users/vajirathambawita/Dropbox (Simula)/CHECK_POINTS/SynGAN-polyps/TrainedModels_1/1 copy/7
# /Users/vajirathambawita/Dropbox (Simula)/CHECK_POINTS/SynGAN-polyps/TrainedModels_1/1 copy/6
# /Users/vajirathambawita/Dropbox (Simula)/CHECK_POINTS/SynGAN-polyps/TrainedModels_1/1 copy/1
# /Users/vajirathambawita/Dropbox (Simula)/CHECK_POINTS/SynGAN-polyps/TrainedModels_1/1 copy/8
# to keep: /Users/vajirathambawita/Dropbox (Simula)/CHECK_POINTS/SynGAN-polyps/TrainedModels_1/1 copy/NoiseAmp.pth
# to keep: /Users/vajirathambawita/Dropbox (Simula)/CHECK_POINTS/SynGAN-polyps/TrainedModels_1/1 copy/Gs.pth
# to keep: /Users/vajirathambawita/Dropbox (Simula)/CHECK_POINTS/SynGAN-polyps/TrainedModels_1/1 copy/reals.pth
# ...
